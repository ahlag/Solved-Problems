# %%
from IPython.display import Image
Image("move_1.png",width=800,height=500)

# %%
def moveZeroes(nums):
    """
    Do not return anything, modify nums in-place instead.
    """
    
    cur = 0
    n = len(nums)
    
    for i in range(n):
        if nums[i] != 0:
            nums[i], nums[cur] = nums[cur], nums[i]
            cur += 1
            
    return nums

nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %%
Image("move_2.png",width=800,height=500)

# %%
Image("move_3.png",width=800,height=500)

# %%
def moveZeroes(nums):
    """
    Do not return anything, modify nums in-place instead.
    """
    
    n = len(nums)
    num_zeroes = 0
    
    for i in range(n):
        if nums[i] == 0:
            num_zeroes += 1
            
    ans = []
    
    for i in range(n):
        if nums[i] != 0:
            ans.append(nums[i])
            
    for i in range(num_zeroes):
        ans.append(0)
    
    nums[:] = ans
    
    return nums

nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %%
Image("move_4.png",width=800,height=500)

# %%
Image("move_5.png",width=800,height=500)

# %%
def moveZeroes(nums):
    """
    Do not return anything, modify nums in-place instead.
    """
    
    n = len(nums)
    last_non_zero_found_at = 0
    
    for i in range(0, n):
        if nums[i] != 0:
            nums[last_non_zero_found_at] = nums[i]
            last_non_zero_found_at += 1
    
    
    for i in range(last_non_zero_found_at, n):
        nums[i] = 0
            
    return nums

nums = [0,1,0,3,12]
moveZeroes(nums)

# %%
Image("move_6.png",width=800,height=500)

# %%
Image("move_7.png",width=800,height=500)

# %%
def moveZeroes(nums):
    """
    Do not return anything, modify nums in-place instead.
    """
    
    cur = 0
    n = len(nums)
    
    for i in range(n):
        if nums[i] != 0:
            nums[i], nums[cur] = nums[cur], nums[i]
            cur += 1
            
    return nums

nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %%
Image("move_8.png",width=800,height=500)
