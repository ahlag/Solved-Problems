# %%
from IPython.display import Image, Video
Image("climbing_1.png",width=900,height=500)

# %%
Image("climbing_2.png",width=900,height=500)

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        
        if i > n:
            return 0
    
        if i == n:
            return 1
    
        return climb_Stairs(n-1) + climb_Stairs(n-2)

# %%
Image("climbing_3.png",width=900,height=500)

# %%
Image("climbing_4.png",width=900,height=500)

# %%
class Solution:
    def climbStairs(self, n: int, cache={0:1, -1: 0}) -> int:
        
        if n in cache:
            return cache[n]
        
        cache[n] = self.climbStairs(n-1) + self.climbStairs(n-2)
        
        return cache[n]

# %%
Image("climbing_5.png",width=900,height=500)

# %%
Video("climbing.mov",width=700,height=300)
# Out:
# <video src="climbing.mov" controls  width="700"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
public class Solution {
    public int climbStairs(int n) {
        if (n == 1) {
            return 1;
        }
        int[] dp = new int[n + 1];
        dp[1] = 1;
        dp[2] = 2;
        for (int i = 3; i <= n; i++) {
            dp[i] = dp[i - 1] + dp[i - 2];
        }
        return dp[n];
    }
}

# %%
Image("climbing_6.png",width=900,height=500)

# %%
Image("climbing_7.png",width=900,height=500)

# %%
## Java
public class Solution {
    public int climbStairs(int n) {
        if (n == 1) {
            return 1;
        }
        int first = 1;
        int second = 2;
        for (int i = 3; i <= n; i++) {
            int third = first + second;
            first = second;
            second = third;
        }
        return second;
    }
}

# %%
Image("climbing_8.png",width=900,height=500)

# %%
## Java
 public class Solution {
    public int climbStairs(int n) {
        int[][] q = {{1, 1}, {1, 0}};
        int[][] res = pow(q, n);
        return res[0][0];
    }
    public int[][] pow(int[][] a, int n) {
        int[][] ret = {{1, 0}, {0, 1}};
        while (n > 0) {
            if ((n & 1) == 1) {
                ret = multiply(ret, a);
            }
            n >>= 1;
            a = multiply(a, a);
        }
        return ret;
    }
    public int[][] multiply(int[][] a, int[][] b) {
        int[][] c = new int[2][2];
        for (int i = 0; i < 2; i++) {
            for (int j = 0; j < 2; j++) {
                c[i][j] = a[i][0] * b[0][j] + a[i][1] * b[1][j];
            }
        }
        return c;
    }
}

# %%
Image("climbing_9.png",width=900,height=500)

# %%
Image("climbing_10.png",width=900,height=500)

# %%
Image("climbing_11.png",width=900,height=500)

# %%
## Java
public class Solution {
    public int climbStairs(int n) {
        double sqrt5=Math.sqrt(5);
        double fibn=Math.pow((1+sqrt5)/2,n+1)-Math.pow((1-sqrt5)/2,n+1);
        return (int)(fibn/sqrt5);
    }
}

# %%
Image("climbing_12.png",width=900,height=500)
