# %%
from IPython.display import Image, Video
Image("cycle_1.png",width=700,height=700)

# %%
Image("cycle_2.png",width=700,height=700)

# %%
Image("cycle_3.png",width=700,height=700)

# %%
Image("cycle_4.png",width=700,height=700)

# %%
Image("cycle_5.png",width=700,height=700)

# %%
Image("cycle_6.png",width=700,height=700)

# %%
Image("cycle_7.png",width=700,height=700)

# %%
Image("cycle_8.png",width=700,height=700)

# %%
Video("cycle.mov",width=700,height=400)
# Out:
# <video src="cycle.mov" controls  width="700"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("cycle_9.png",width=700,height=700)
