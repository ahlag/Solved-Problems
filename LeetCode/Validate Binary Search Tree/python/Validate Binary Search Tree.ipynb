# %%
from IPython.display import Image, Video
Image("validate_1.png",width=700,height=500)

# %%
Image("validate_2.png",width=700,height=500)

# %%
Image("validate_3.png",width=700,height=500)

# %%
Image("validate_4.png",width=700,height=500)

# %%
Image("validate_5.png",width=700,height=500)

# %%
Image("validate_6.png",width=700,height=500)

# %%
Video("validate.mov",width=700,height=400)
# Out:
# <video src="validate.mov" controls  width="700"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:

        def validate(node, low=-math.inf, high=math.inf):
            # Empty trees are valid BSTs.
            if not node:
                return True
            # The current node's value must be between low and high.
            if node.val <= low or node.val >= high:
                return False

            # The left and right subtree must also be valid.
            return (validate(node.right, node.val, high) and
                   validate(node.left, low, node.val))

        return validate(root)

# %%
Image("validate_6.png",width=700,height=500)

# %%
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        if not root:
            return True

        stack = [(root, -math.inf, math.inf)]
        while stack:
            root, lower, upper = stack.pop()
            if not root:
                continue
            val = root.val
            if val <= lower or val >= upper:
                return False
            stack.append((root.right, val, upper))
            stack.append((root.left, lower, val))
        return True

# %%
Image("validate_7.png",width=700,height=500)

# %%
Image("validate_8.png",width=700,height=500)

# %%
Image("validate_9.png",width=700,height=500)

# %%
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:

        def inorder(root):
            if not root:
                return True
            if not inorder(root.left):
                return False
            if root.val <= self.prev:
                return False
            self.prev = root.val
            return inorder(root.right)

        self.prev = -math.inf
        return inorder(root)

# %%
Image("validate_10.png",width=700,height=500)

# %%
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        stack, prev = [], -math.inf

        while stack or root:
            while root:
                stack.append(root)
                root = root.left
            root = stack.pop()
            # If next element in inorder traversal
            # is smaller than the previous one
            # that's not BST.
            if root.val <= prev:
                return False
            prev = root.val
            root = root.right

        return True

# %%
Image("validate_11.png",width=700,height=500)
